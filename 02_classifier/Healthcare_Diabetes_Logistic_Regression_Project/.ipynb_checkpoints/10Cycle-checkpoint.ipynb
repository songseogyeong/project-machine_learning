# %% [markdown]
# # Healthcare Diabetes Classifier Project (Logistic_Regression)
# ## 당뇨병 진단 예측
# - 당뇨병이 양성인지 음성인지 예측
#
# #### feature (22개)
# - Id: 각 데이터 항목의 고유 식별자
# - Pregnancies: 임신 횟수
# - Glucose: 경구 포도당 내성 테스트에서 2시간 동안의 혈장 포도당 농도
# - BloodPressure: 확장기 혈압(mmHg)
# - SkinThickness: 삼두근 피부주름 두께(mm)
# - Insulin: 2시간 혈청 인슐린(mu U/ml)
# - BMI: 체질량 지수(체중(kg) / 키(m^2))
# - DiabetesPedigreeFunction: 당뇨병의 유전적 점수인 당뇨병 혈통 기능
# - Age: 나이(년)
#
#
# #### target
# - Outcome: 당뇨병의 존재(1) 또는 부재(0)를 나타내는 이진 분류

# %%
import pandas as pd

# 데이터 세트 호출
h_df = pd.read_csv('./datasets/Healthcare_Diabetes.csv', low_memory=False)
h_df
# Out:
#         Id  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        1            6      148             72             35        0  33.6
# 1        2            1       85             66             29        0  26.6
# 2        3            8      183             64              0        0  23.3
# 3        4            1       89             66             23       94  28.1
# 4        5            0      137             40             35      168  43.1
# ...    ...          ...      ...            ...            ...      ...   ...
# 2763  2764            2       75             64             24       55  29.7
# 2764  2765            8      179             72             42      130  32.7
# 2765  2766            6       85             78              0        0  31.2
# 2766  2767            0      129            110             46      130  67.1
# 2767  2768            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.627   50        1
# 1                        0.351   31        0
# 2                        0.672   32        1
# 3                        0.167   21        0
# 4                        2.288   33        1
# ...                        ...  ...      ...
# 2763                     0.370   33        0
# 2764                     0.719   36        1
# 2765                     0.382   42        0
# 2766                     0.319   26        1
# 2767                     0.547   25        0
#
# [2768 rows x 10 columns]

# %% [markdown]
# #### 📊 데이터 탐색

# %%
import matplotlib.pyplot as plt
import numpy as np

# 한글 폰트 경로 설정
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# 컬러맵 가져오기
cmap = plt.get_cmap('Pastel1')
# 컬러맵의 색상 선택
outer_colors = cmap(np.array([0, 1, 2, 3, 4, 5, 6]))

# %% [markdown]
# ### 🌟 1Cycle

# %% [markdown]
# #### 📊 전처리

# %%
# 불필요한 데이터 세트 제거 (id 컬럼)
pre_h_df = h_df.drop(labels='Id', axis=1)

# %%
# 언더 샘플링
Outcome0 = pre_h_df[pre_h_df.Outcome == 0].sample(952, random_state=124)
Outcome1 = pre_h_df[pre_h_df.Outcome == 1]
pre_h_df = pd.concat([Outcome0, Outcome1]).reset_index(drop=True)

# %% [markdown]
# #### 🚩 1Cycle 결과
# - Logistic Regression
# **정확도: 0.7349, 정밀도: 0.7380, 재현율: 0.7263, F1:0.7321, AUC:0.7349**

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 2Cycle

# %%
# 수치형 데이터 이상치 제거
from sklearn.preprocessing import StandardScaler

std_pre_h_df = pre_h_df.copy()
columns = ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction']

for column in columns:
    # 표준화 객체 생성
    std = StandardScaler()
    # 데이터 표준화 변환
    result = std.fit_transform(pre_h_df[[column]])
    # 표준화 데이터 프레임 생성
    std_pre_h_df[column] = result

for column in columns:
    # 타겟 데이터 이상치 제거
    std_pre_h_df = std_pre_h_df[std_pre_h_df[column].between(-1.96, 1.96)]

# 이상치 제거 후 유지되는 인덱스를 대조하여 원본 데이터 이상치 제거
pre_h_df = pre_h_df.iloc[std_pre_h_df.index].reset_index(drop=True)

# %% [markdown]
# #### 🚩 1Cycle 결과
# - Logistic Regression
# **정확도: 0.7349, 정밀도: 0.7380, 재현율: 0.7263, F1:0.7321, AUC:0.7349**
#
# #### 🚩 2Cycle 결과
# - 전처리 후 Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 💡 분석
# - 이상치 제거 후 성능이 향상된 것을 확인함.
# - 최소-최대 스케일링(min-max scaling)을 통해 값을 정규화하여 성능 차이를 비교하기로 함.

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 3Cycle

# %% [markdown]
# #### 🚩 2Cycle 결과
# - Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 🚩 3Cycle 결과
# - Min-Max Scaling
# **정확도: 0.7722, 정밀도: 0.7569, 재현율: 0.7466, F1:0.7517, AUC:0.7703**
#
# #### 💡 분석
# - Min-Max Scaling 시 이전 보다 성능이 저하됨에 따라 해당 전처리를 진행하지 않기로 함.
# - 피처 이상치 제거 후 성능 평가를 진행하기로 함.

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 4Cycle

# %% [markdown]
# #### 🚩 2Cycle 결과
# - Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 🚩 4Cycle 결과
# - 피처 이상치 제거
# **정확도: 0.7716, 정밀도: 0.7474, 재현율: 0.7100, F1:0.7282, AUC:0.7641**
#
# #### 💡 분석
# - 피처 이상치 제거 시 이전 보다 성능이 저하됨에 따라 해당 전처리를 진행하지 않기로 함.
# - 0과 같은 특정 데이터가 높게 나타나는 SkinThickness, lnsulin의 일부 데이터의 전처리를 진행하고자 함.

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 5Cycle

# %% [markdown]
# #### 🚩 2Cycle 결과
# - Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 🚩 4Cycle 결과
# - 피처 이상치 제거
# **정확도: 0.7716, 정밀도: 0.7474, 재현율: 0.7100, F1:0.7282, AUC:0.7641**
#
# #### 🚩 5Cycle 결과
# - 특정 피처 이상치 제거
# **정확도: 0.7917, 정밀도: 0.8000, 재현율: 0.6087, F1:0.6914, AUC:0.7571**
#
# #### 💡 분석
# - 특정 피처 이상치 제거 시 오히려 성능이 저하되는 것을 확인함.
# - 해당 전처리는 진행하지 않는 것으로 하며, 분포 변환을 별도로 진행하기로 함.

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 6Cycle

# %% [markdown]
# #### 🚩 2Cycle 결과
# - Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 🚩 6Cycle 결과
# - 분포 변환
# **정확도: 0.7880, 정밀도: 0.7801, 재현율: 0.7534, F1:0.7666, AUC:0.7855**
#
# #### 💡 분석
# - 분포 변환 후 성능이 근소하게 하락함에 따라 해당 전처리를 진행하지 않는 것으로 함.
# - 차원축소를 진행하여 성능으

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 7~8Cycle

# %% [markdown]
# #### 🚩 2Cycle 결과
# - Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 🚩 7Cycle 결과
# - PCA
# **정확도: 0.7405, 정밀도: 0.7462, 재현율: 0.6644, F1:0.7029, AUC:0.7351**
#
# #### 🚩 8Cycle 결과
# - LDA
# **정확도: 0.2184, 정밀도: 0.1656, 재현율: 0.1712, F1:0.1684, AUC:0.2150**
#
# #### 💡 분석
# - 차원축소 진행 후 성능이 많이 하락한 것을 확인할 수 있음.
# - 상관관계, 다중 공산성 등을 확인하여 전처리 진행 후 성능 평가를 진행하고자 함.

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 9Cycle

# %%
# 상관 관계가 낮은 피처 제거
pre_h_df = pre_h_df.drop(labels=['SkinThickness'], axis=1)

# %% [markdown]
# #### 🚩 2Cycle 결과
# - Logistic Regression
# **정확도: 0.7911, 정밀도: 0.7817, 재현율: 0.7603, F1:0.7708, AUC:0.7890**
#
# #### 🚩 9Cycle 결과
# - 상관관계
# **정확도: 0.7943, 정밀도: 0.7872, 재현율: 0.7603, F1:0.7735, AUC:0.7919**
#
# #### 💡 분석
# - 상관관계 등 다양한 지표 확인 후 관계가 낮은 피처를 제거한 결과 성능이 향상된 것을 확인함.
# - 전처리된 데이터를 토대로 임계값을 조정하려 함.

# %% [markdown]
# ---

# %% [markdown]
# ### 🌟 10Cycle

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score
import matplotlib.pyplot as plt

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction)
    recall = recall_score(y_test , prediction)
    f1 = f1_score(y_test, prediction)
    roc_auc = roc_auc_score(y_test, prediction)

    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}, AUC:{4:.4f}'.format(accuracy , precision ,recall, f1, roc_auc))
    print("#" * 75)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from imblearn.over_sampling import SMOTE

# 데이터 세트 분리
# 피처, 타겟 데이터 분리
features, targets = pre_h_df.iloc[:, :-1], pre_h_df.iloc[:, -1]

# 문제/정답 및 훈련/테스트 데이터 분리 
X_train, X_test, y_train, y_test = \
train_test_split(features, targets, test_size=0.2, stratify=targets, random_state=124)

# 객체 생성
# solver: 최적화에 사용되는 알고리즘 (liblinear: 작은 데이터 세트 사용)
# penalty: 규제 유형 (l2 = L2 규제)
lg = LogisticRegression(solver='liblinear', penalty='l2', random_state=124)

# 훈련
lg.fit(X_train, y_train)

# 예측
prediction = lg.predict(X_test)

# %%
get_evaluation(y_test, prediction, lg, X_test)
# Out:
# 오차 행렬
# [[140  30]
#  [ 35 111]]
# 정확도: 0.7943, 정밀도: 0.7872, 재현율: 0.7603, F1:0.7735, AUC:0.7919
# ###########################################################################

# %% [markdown]
# ##### 시나리오: 당뇨병이 음성 환자인지 양성 환자인지 분류하는 의료 진단
#
# - 음성(Negative): 당뇨병 음성 환자를 의미.
# - 양성(Positive): 당뇨병 양성 환자를 의미.
#
# <br>
#
# #### 문제: 당뇨병 진단
#
# >True Positive (TP): 모델이 양성 환자를 양성으로 올바르게 분류한 경우.
# False Positive (FP): 모델이 음성 환자를 양성으로 잘못 분류한 경우(오진, error I).
# True Negative (TN): 모델이 음성 환자를 음성으로 올바르게 분류한 경우.
# False Negative (FN): 모델이 양성 환자를 음성으로 잘못 분류한 경우(놓침, error II).
#
# <br>
#
# >정밀도 (Precision): 모델이 양성으로 예측한 환자 중에서 실제로 양성인 환자의 비율을 나타낸다.
# >즉, 음성 클래스로 예측한 결과 중 얼마나 많은 것이 진짜 음성인지 측정한다.
#
# >재현율 (Recall): 실제 양성 환자 중에서 모델이 양성으로 정확하게 예측한 환자의 비율을 나타낸다.
# >즉, 모델이 얼마나 많은 양성 환자를 "놓치지 않고" 감지했는지 측정한다.
#
# <br>
#
# > 🏆 양성인 환자를 놓치지 않는 것이 중요하다고 판단되므로, 임계치를 낮춰서 재현율을 높여주는 것이 적합하다.

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.metrics import precision_recall_curve

def precision_recall_curve_plot(y_test , prediction_proba_class1):

    precisions, recalls, thresholds = precision_recall_curve(y_test, prediction_proba_class1)
    
    # X축: threshold
    # Y축: 정밀도, 재현율 
    # 정밀도는 점선으로 표시
    plt.figure(figsize=(8,6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle='--', label='precision')
    plt.plot(thresholds, recalls[0:threshold_boundary],label='recall')
    
    # X축(threshold)의 Scale을 0 ~ 1 단위로 변경
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend()
    plt.grid()
    plt.show()
    
precision_recall_curve_plot(y_test, lg.predict_proba(X_test)[:, 1] )

# %%
# 임계값 확인
_, _, thresholds = precision_recall_curve(y_test, lg.predict_proba(X_test)[:, 1])
thresholds
# Out:
# array([0.03416928, 0.05021441, 0.05792394, 0.06188758, 0.0629915 ,
#        0.06566293, 0.06637941, 0.06879383, 0.07079115, 0.08218249,
#        0.08328495, 0.08539059, 0.09078187, 0.09107988, 0.09839676,
#        0.10330926, 0.1040402 , 0.10942157, 0.11010543, 0.11088557,
#        0.12332149, 0.12512045, 0.12831012, 0.12922972, 0.13244063,
#        0.13306507, 0.13419009, 0.13890413, 0.13905545, 0.14294163,
#        0.14500856, 0.15299574, 0.15528051, 0.15780512, 0.1594876 ,
#        0.16293632, 0.16642869, 0.17104361, 0.17243519, 0.177712  ,
#        0.17774014, 0.18115655, 0.18605137, 0.19239394, 0.1945519 ,
#        0.1948144 , 0.19767149, 0.2093649 , 0.21084856, 0.2136213 ,
#        0.21881158, 0.22204688, 0.22556254, 0.22673811, 0.23016943,
#        0.23129684, 0.23493224, 0.23552317, 0.23619684, 0.23703033,
#        0.23726349, 0.24151462, 0.24314921, 0.24337806, 0.24804607,
#        0.2495723 , 0.25810619, 0.26230771, 0.26231062, 0.26476932,
#        0.26560301, 0.26659131, 0.26693146, 0.27394669, 0.27482645,
#        0.27970839, 0.28097872, 0.28473863, 0.28700418, 0.290524  ,
#        0.29180449, 0.2935731 , 0.29482111, 0.3024046 , 0.30275152,
#        0.3057825 , 0.30731886, 0.30900967, 0.31455264, 0.31571137,
#        0.31584266, 0.31697536, 0.32226345, 0.32394052, 0.32563918,
#        0.33026293, 0.33217633, 0.34594427, 0.34643714, 0.34681407,
#        0.34719038, 0.34856117, 0.35564806, 0.35946015, 0.35992404,
#        0.36499507, 0.36546162, 0.36555646, 0.37038426, 0.37136923,
#        0.37693999, 0.37854845, 0.37984013, 0.39247704, 0.39473339,
#        0.39563875, 0.39789327, 0.41297517, 0.41752772, 0.41782865,
#        0.41908838, 0.41985219, 0.42522953, 0.42633622, 0.42832717,
#        0.42874094, 0.43620296, 0.4373489 , 0.43964003, 0.44040012,
#        0.44248273, 0.44453437, 0.45125099, 0.45357718, 0.45426099,
#        0.45512107, 0.45864963, 0.46275922, 0.46653051, 0.46952857,
#        0.47273098, 0.47326754, 0.48689267, 0.48758343, 0.49212196,
#        0.49668719, 0.50261012, 0.5060678 , 0.51150449, 0.51641398,
#        0.5174481 , 0.52299861, 0.52423982, 0.52711327, 0.52811379,
#        0.53579709, 0.53719536, 0.54383261, 0.54465279, 0.55226057,
#        0.55232778, 0.55258768, 0.55424577, 0.5570066 , 0.56050779,
#        0.56168003, 0.56584346, 0.57003737, 0.57640053, 0.57744386,
#        0.57913268, 0.58397521, 0.59150157, 0.5939769 , 0.5951462 ,
#        0.60580648, 0.61148345, 0.61254636, 0.61431787, 0.61442041,
#        0.62177579, 0.64104334, 0.64471475, 0.65501275, 0.65778016,
#        0.66155037, 0.66243713, 0.66616174, 0.67263009, 0.67552923,
#        0.68542051, 0.695929  , 0.70868064, 0.71058758, 0.71060653,
#        0.71468703, 0.72152933, 0.73115647, 0.73528734, 0.74077695,
#        0.74206535, 0.76506315, 0.77806303, 0.77816087, 0.78009536,
#        0.78396097, 0.78405276, 0.78429315, 0.78694728, 0.79238866,
#        0.80653897, 0.80789326, 0.81079082, 0.81096088, 0.82381262,
#        0.82723554, 0.82879056, 0.83225359, 0.84099961, 0.84631961,
#        0.84700101, 0.84759102, 0.84846079, 0.84864929, 0.84921403,
#        0.84925132, 0.85043437, 0.85123611, 0.85300305, 0.85486829,
#        0.86189517, 0.86510868, 0.86613378, 0.86634957, 0.86681912,
#        0.87276224, 0.87565078, 0.87713896, 0.88659273, 0.8885321 ,
#        0.90315061, 0.90438233, 0.90790598, 0.91312541, 0.92088789,
#        0.92381941, 0.92848402, 0.93049645, 0.93226466, 0.93786371,
#        0.94028589, 0.94938138, 0.95121115, 0.96774468, 0.98032473])

# %%
from sklearn.preprocessing import Binarizer
def get_evaluation_by_thresholds(y_test, prediction_proba_class1, thresholds):
    
    for threshold in thresholds:
        binarizer = Binarizer(threshold=threshold).fit(prediction_proba_class1) 
        custom_prediction = binarizer.transform(prediction_proba_class1)
        print('임곗값:', threshold)
        get_evaluation(y_test, custom_prediction)

# %%
# 임계값 조정
get_evaluation_by_thresholds(y_test, lg.predict_proba(X_test)[:, 1].reshape(-1, 1), thresholds)
# Out:
# 임곗값: 0.034169278370831245
# 오차 행렬
# [[  1 169]
#  [  0 146]]
# 정확도: 0.4652, 정밀도: 0.4635, 재현율: 1.0000, F1:0.6334, AUC:0.5029
# ###########################################################################
# 임곗값: 0.05021441081822234
# 오차 행렬
# [[  2 168]
#  [  0 146]]
# 정확도: 0.4684, 정밀도: 0.4650, 재현율: 1.0000, F1:0.6348, AUC:0.5059
# ###########################################################################
# 임곗값: 0.05792393799178727
# 오차 행렬
# [[  3 167]
#  [  0 146]]
# 정확도: 0.4715, 정밀도: 0.4665, 재현율: 1.0000, F1:0.6362, AUC:0.5088
# ###########################################################################
# 임곗값: 0.061887583733416796
# 오차 행렬
# [[  6 164]
#  [  0 146]]
# 정확도: 0.4810, 정밀도: 0.4710, 재현율: 1.0000, F1:0.6404, AUC:0.5176
# ###########################################################################
# 임곗값: 0.06299149838941452
# 오차 행렬
# [[  7 163]
#  [  0 146]]
# 정확도: 0.4842, 정밀도: 0.4725, 재현율: 1.0000, F1:0.6418, AUC:0.5206
# ###########################################################################
# 임곗값: 0.06566292934399899
# 오차 행렬
# [[  8 162]
#  [  0 146]]
# 정확도: 0.4873, 정밀도: 0.4740, 재현율: 1.0000, F1:0.6432, AUC:0.5235
# ###########################################################################
# 임곗값: 0.06637941014866255
# 오차 행렬
# [[ 10 160]
#  [  0 146]]
# 정확도: 0.4937, 정밀도: 0.4771, 재현율: 1.0000, F1:0.6460, AUC:0.5294
# ###########################################################################
# 임곗값: 0.06879382511845908
# 오차 행렬
# [[ 11 159]
#  [  0 146]]
# 정확도: 0.4968, 정밀도: 0.4787, 재현율: 1.0000, F1:0.6475, AUC:0.5324
# ###########################################################################
# 임곗값: 0.0707911464252649
# 오차 행렬
# [[ 13 157]
#  [  0 146]]
# 정확도: 0.5032, 정밀도: 0.4818, 재현율: 1.0000, F1:0.6503, AUC:0.5382
# ###########################################################################
# 임곗값: 0.0821824858763704
# 오차 행렬
# [[ 14 156]
#  [  0 146]]
# 정확도: 0.5063, 정밀도: 0.4834, 재현율: 1.0000, F1:0.6518, AUC:0.5412
# ###########################################################################
# 임곗값: 0.08328495127050566
# 오차 행렬
# [[ 15 155]
#  [  0 146]]
# 정확도: 0.5095, 정밀도: 0.4850, 재현율: 1.0000, F1:0.6532, AUC:0.5441
# ###########################################################################
# 임곗값: 0.08539058762286739
# 오차 행렬
# [[ 16 154]
#  [  0 146]]
# 정확도: 0.5127, 정밀도: 0.4867, 재현율: 1.0000, F1:0.6547, AUC:0.5471
# ###########################################################################
# 임곗값: 0.09078187315278961
# 오차 행렬
# [[ 17 153]
#  [  0 146]]
# 정확도: 0.5158, 정밀도: 0.4883, 재현율: 1.0000, F1:0.6562, AUC:0.5500
# ###########################################################################
# 임곗값: 0.09107988200454213
# 오차 행렬
# [[ 18 152]
#  [  0 146]]
# 정확도: 0.5190, 정밀도: 0.4899, 재현율: 1.0000, F1:0.6577, AUC:0.5529
# ###########################################################################
# 임곗값: 0.09839676126235512
# 오차 행렬
# [[ 20 150]
#  [  0 146]]
# 정확도: 0.5253, 정밀도: 0.4932, 재현율: 1.0000, F1:0.6606, AUC:0.5588
# ###########################################################################
# 임곗값: 0.10330926072374788
# 오차 행렬
# [[ 21 149]
#  [  0 146]]
# 정확도: 0.5285, 정밀도: 0.4949, 재현율: 1.0000, F1:0.6621, AUC:0.5618
# ###########################################################################
# 임곗값: 0.10404020161185801
# 오차 행렬
# [[ 23 147]
#  [  0 146]]
# 정확도: 0.5348, 정밀도: 0.4983, 재현율: 1.0000, F1:0.6651, AUC:0.5676
# ###########################################################################
# 임곗값: 0.1094215662178992
# 오차 행렬
# [[ 24 146]
#  [  0 146]]
# 정확도: 0.5380, 정밀도: 0.5000, 재현율: 1.0000, F1:0.6667, AUC:0.5706
# ###########################################################################
# 임곗값: 0.11010543137689785
# 오차 행렬
# [[ 25 145]
#  [  0 146]]
# 정확도: 0.5411, 정밀도: 0.5017, 재현율: 1.0000, F1:0.6682, AUC:0.5735
# ###########################################################################
# 임곗값: 0.11088557334805381
# 오차 행렬
# [[ 26 144]
#  [  0 146]]
# 정확도: 0.5443, 정밀도: 0.5034, 재현율: 1.0000, F1:0.6697, AUC:0.5765
# ###########################################################################
# 임곗값: 0.12332148597727322
# 오차 행렬
# [[ 27 143]
#  [  0 146]]
# 정확도: 0.5475, 정밀도: 0.5052, 재현율: 1.0000, F1:0.6713, AUC:0.5794
# ###########################################################################
# 임곗값: 0.1251204506854859
# 오차 행렬
# [[ 28 142]
#  [  0 146]]
# 정확도: 0.5506, 정밀도: 0.5069, 재현율: 1.0000, F1:0.6728, AUC:0.5824
# ###########################################################################
# 임곗값: 0.12831011917740737
# 오차 행렬
# [[ 29 141]
#  [  0 146]]
# 정확도: 0.5538, 정밀도: 0.5087, 재현율: 1.0000, F1:0.6744, AUC:0.5853
# ###########################################################################
# 임곗값: 0.12922972460166465
# 오차 행렬
# [[ 30 140]
#  [  0 146]]
# 정확도: 0.5570, 정밀도: 0.5105, 재현율: 1.0000, F1:0.6759, AUC:0.5882
# ###########################################################################
# 임곗값: 0.13244063019799263
# 오차 행렬
# [[ 31 139]
#  [  0 146]]
# 정확도: 0.5601, 정밀도: 0.5123, 재현율: 1.0000, F1:0.6775, AUC:0.5912
# ###########################################################################
# 임곗값: 0.133065071317501
# 오차 행렬
# [[ 33 137]
#  [  0 146]]
# 정확도: 0.5665, 정밀도: 0.5159, 재현율: 1.0000, F1:0.6807, AUC:0.5971
# ###########################################################################
# 임곗값: 0.13419008786439043
# 오차 행렬
# [[ 34 136]
#  [  0 146]]
# 정확도: 0.5696, 정밀도: 0.5177, 재현율: 1.0000, F1:0.6822, AUC:0.6000
# ###########################################################################
# 임곗값: 0.13890413487005857
# 오차 행렬
# [[ 35 135]
#  [  0 146]]
# 정확도: 0.5728, 정밀도: 0.5196, 재현율: 1.0000, F1:0.6838, AUC:0.6029
# ###########################################################################
# 임곗값: 0.1390554537641192
# 오차 행렬
# [[ 36 134]
#  [  0 146]]
# 정확도: 0.5759, 정밀도: 0.5214, 재현율: 1.0000, F1:0.6854, AUC:0.6059
# ###########################################################################
# 임곗값: 0.14294163441646235
# 오차 행렬
# [[ 37 133]
#  [  0 146]]
# 정확도: 0.5791, 정밀도: 0.5233, 재현율: 1.0000, F1:0.6871, AUC:0.6088
# ###########################################################################
# 임곗값: 0.145008563208205
# 오차 행렬
# [[ 38 132]
#  [  0 146]]
# 정확도: 0.5823, 정밀도: 0.5252, 재현율: 1.0000, F1:0.6887, AUC:0.6118
# ###########################################################################
# 임곗값: 0.15299573803640512
# 오차 행렬
# [[ 39 131]
#  [  0 146]]
# 정확도: 0.5854, 정밀도: 0.5271, 재현율: 1.0000, F1:0.6903, AUC:0.6147
# ###########################################################################
# 임곗값: 0.15528050910941774
# 오차 행렬
# [[ 40 130]
#  [  0 146]]
# 정확도: 0.5886, 정밀도: 0.5290, 재현율: 1.0000, F1:0.6919, AUC:0.6176
# ###########################################################################
# 임곗값: 0.1578051178591784
# 오차 행렬
# [[ 41 129]
#  [  0 146]]
# 정확도: 0.5918, 정밀도: 0.5309, 재현율: 1.0000, F1:0.6936, AUC:0.6206
# ###########################################################################
# 임곗값: 0.15948760467893303
# 오차 행렬
# [[ 43 127]
#  [  0 146]]
# 정확도: 0.5981, 정밀도: 0.5348, 재현율: 1.0000, F1:0.6969, AUC:0.6265
# ###########################################################################
# 임곗값: 0.16293632126516014
# 오차 행렬
# [[ 44 126]
#  [  0 146]]
# 정확도: 0.6013, 정밀도: 0.5368, 재현율: 1.0000, F1:0.6986, AUC:0.6294
# ###########################################################################
# 임곗값: 0.16642869255702783
# 오차 행렬
# [[ 46 124]
#  [  0 146]]
# 정확도: 0.6076, 정밀도: 0.5407, 재현율: 1.0000, F1:0.7019, AUC:0.6353
# ###########################################################################
# 임곗값: 0.1710436056289236
# 오차 행렬
# [[ 46 124]
#  [  1 145]]
# 정확도: 0.6044, 정밀도: 0.5390, 재현율: 0.9932, F1:0.6988, AUC:0.6319
# ###########################################################################
# 임곗값: 0.1724351856307742
# 오차 행렬
# [[ 47 123]
#  [  1 145]]
# 정확도: 0.6076, 정밀도: 0.5410, 재현율: 0.9932, F1:0.7005, AUC:0.6348
# ###########################################################################
# 임곗값: 0.17771199787415273
# 오차 행렬
# [[ 49 121]
#  [  1 145]]
# 정확도: 0.6139, 정밀도: 0.5451, 재현율: 0.9932, F1:0.7039, AUC:0.6407
# ###########################################################################
# 임곗값: 0.17774014258736265
# 오차 행렬
# [[ 51 119]
#  [  1 145]]
# 정확도: 0.6203, 정밀도: 0.5492, 재현율: 0.9932, F1:0.7073, AUC:0.6466
# ###########################################################################
# 임곗값: 0.18115655054781438
# 오차 행렬
# [[ 52 118]
#  [  1 145]]
# 정확도: 0.6234, 정밀도: 0.5513, 재현율: 0.9932, F1:0.7090, AUC:0.6495
# ###########################################################################
# 임곗값: 0.18605137067532315
# 오차 행렬
# [[ 53 117]
#  [  1 145]]
# 정확도: 0.6266, 정밀도: 0.5534, 재현율: 0.9932, F1:0.7108, AUC:0.6525
# ###########################################################################
# 임곗값: 0.19239393524713466
# 오차 행렬
# [[ 54 116]
#  [  1 145]]
# 정확도: 0.6297, 정밀도: 0.5556, 재현율: 0.9932, F1:0.7125, AUC:0.6554
# ###########################################################################
# 임곗값: 0.1945518983353398
# 오차 행렬
# [[ 55 115]
#  [  1 145]]
# 정확도: 0.6329, 정밀도: 0.5577, 재현율: 0.9932, F1:0.7143, AUC:0.6583
# ###########################################################################
# 임곗값: 0.1948143983198623
# 오차 행렬
# [[ 56 114]
#  [  1 145]]
# 정확도: 0.6361, 정밀도: 0.5598, 재현율: 0.9932, F1:0.7160, AUC:0.6613
# ###########################################################################
# 임곗값: 0.19767148592347103
# 오차 행렬
# [[ 57 113]
#  [  1 145]]
# 정확도: 0.6392, 정밀도: 0.5620, 재현율: 0.9932, F1:0.7178, AUC:0.6642
# ###########################################################################
# 임곗값: 0.20936490257417767
# 오차 행렬
# [[ 58 112]
#  [  1 145]]
# 정확도: 0.6424, 정밀도: 0.5642, 재현율: 0.9932, F1:0.7196, AUC:0.6672
# ###########################################################################
# 임곗값: 0.21084856439515018
# 오차 행렬
# [[ 59 111]
#  [  1 145]]
# 정확도: 0.6456, 정밀도: 0.5664, 재현율: 0.9932, F1:0.7214, AUC:0.6701
# ###########################################################################
# 임곗값: 0.21362129603516955
# 오차 행렬
# [[ 61 109]
#  [  1 145]]
# 정확도: 0.6519, 정밀도: 0.5709, 재현율: 0.9932, F1:0.7250, AUC:0.6760
# ###########################################################################
# 임곗값: 0.21881157732149165
# 오차 행렬
# [[ 62 108]
#  [  1 145]]
# 정확도: 0.6551, 정밀도: 0.5731, 재현율: 0.9932, F1:0.7268, AUC:0.6789
# ###########################################################################
# 임곗값: 0.22204688281095375
# 오차 행렬
# [[ 63 107]
#  [  1 145]]
# 정확도: 0.6582, 정밀도: 0.5754, 재현율: 0.9932, F1:0.7286, AUC:0.6819
# ###########################################################################
# 임곗값: 0.22556253915010485
# 오차 행렬
# [[ 64 106]
#  [  1 145]]
# 정확도: 0.6614, 정밀도: 0.5777, 재현율: 0.9932, F1:0.7305, AUC:0.6848
# ###########################################################################
# 임곗값: 0.22673810785164683
# 오차 행렬
# [[ 64 106]
#  [  2 144]]
# 정확도: 0.6582, 정밀도: 0.5760, 재현율: 0.9863, F1:0.7273, AUC:0.6814
# ###########################################################################
# 임곗값: 0.23016942843645422
# 오차 행렬
# [[ 65 105]
#  [  2 144]]
# 정확도: 0.6614, 정밀도: 0.5783, 재현율: 0.9863, F1:0.7291, AUC:0.6843
# ###########################################################################
# 임곗값: 0.23129683995140268
# 오차 행렬
# [[ 66 104]
#  [  2 144]]
# 정확도: 0.6646, 정밀도: 0.5806, 재현율: 0.9863, F1:0.7310, AUC:0.6873
# ###########################################################################
# 임곗값: 0.2349322384315268
# 오차 행렬
# [[ 66 104]
#  [  5 141]]
# 정확도: 0.6551, 정밀도: 0.5755, 재현율: 0.9658, F1:0.7212, AUC:0.6770
# ###########################################################################
# 임곗값: 0.23552316786407898
# 오차 행렬
# [[ 67 103]
#  [  5 141]]
# 정확도: 0.6582, 정밀도: 0.5779, 재현율: 0.9658, F1:0.7231, AUC:0.6799
# ###########################################################################
# 임곗값: 0.23619684073684144
# 오차 행렬
# [[ 68 102]
#  [  5 141]]
# 정확도: 0.6614, 정밀도: 0.5802, 재현율: 0.9658, F1:0.7249, AUC:0.6829
# ###########################################################################
# 임곗값: 0.23703032512605274
# 오차 행렬
# [[ 69 101]
#  [  5 141]]
# 정확도: 0.6646, 정밀도: 0.5826, 재현율: 0.9658, F1:0.7268, AUC:0.6858
# ###########################################################################
# 임곗값: 0.2372634920253474
# 오차 행렬
# [[ 70 100]
#  [  5 141]]
# 정확도: 0.6677, 정밀도: 0.5851, 재현율: 0.9658, F1:0.7287, AUC:0.6888
# ###########################################################################
# 임곗값: 0.24151461521579237
# 오차 행렬
# [[ 71  99]
#  [  5 141]]
# 정확도: 0.6709, 정밀도: 0.5875, 재현율: 0.9658, F1:0.7306, AUC:0.6917
# ###########################################################################
# 임곗값: 0.24314921466026307
# 오차 행렬
# [[ 72  98]
#  [  5 141]]
# 정확도: 0.6741, 정밀도: 0.5900, 재현율: 0.9658, F1:0.7325, AUC:0.6946
# ###########################################################################
# 임곗값: 0.24337806440733528
# 오차 행렬
# [[ 72  98]
#  [  6 140]]
# 정확도: 0.6709, 정밀도: 0.5882, 재현율: 0.9589, F1:0.7292, AUC:0.6912
# ###########################################################################
# 임곗값: 0.24804607275595955
# 오차 행렬
# [[ 73  97]
#  [  6 140]]
# 정확도: 0.6741, 정밀도: 0.5907, 재현율: 0.9589, F1:0.7311, AUC:0.6942
# ###########################################################################
# 임곗값: 0.24957229889113314
# 오차 행렬
# [[ 74  96]
#  [  6 140]]
# 정확도: 0.6772, 정밀도: 0.5932, 재현율: 0.9589, F1:0.7330, AUC:0.6971
# ###########################################################################
# 임곗값: 0.2581061934573224
# 오차 행렬
# [[ 75  95]
#  [  6 140]]
# 정확도: 0.6804, 정밀도: 0.5957, 재현율: 0.9589, F1:0.7349, AUC:0.7000
# ###########################################################################
# 임곗값: 0.2623077076287438
# 오차 행렬
# [[ 76  94]
#  [  6 140]]
# 정확도: 0.6835, 정밀도: 0.5983, 재현율: 0.9589, F1:0.7368, AUC:0.7030
# ###########################################################################
# 임곗값: 0.26231062006613787
# 오차 행렬
# [[ 77  93]
#  [  6 140]]
# 정확도: 0.6867, 정밀도: 0.6009, 재현율: 0.9589, F1:0.7388, AUC:0.7059
# ###########################################################################
# 임곗값: 0.26476931968063033
# 오차 행렬
# [[ 78  92]
#  [  6 140]]
# 정확도: 0.6899, 정밀도: 0.6034, 재현율: 0.9589, F1:0.7407, AUC:0.7089
# ###########################################################################
# 임곗값: 0.2656030059471952
# 오차 행렬
# [[ 79  91]
#  [  6 140]]
# 정확도: 0.6930, 정밀도: 0.6061, 재현율: 0.9589, F1:0.7427, AUC:0.7118
# ###########################################################################
# 임곗값: 0.26659131194891983
# 오차 행렬
# [[ 80  90]
#  [  6 140]]
# 정확도: 0.6962, 정밀도: 0.6087, 재현율: 0.9589, F1:0.7447, AUC:0.7147
# ###########################################################################
# 임곗값: 0.2669314610408986
# 오차 행렬
# [[ 82  88]
#  [  6 140]]
# 정확도: 0.7025, 정밀도: 0.6140, 재현율: 0.9589, F1:0.7487, AUC:0.7206
# ###########################################################################
# 임곗값: 0.27394669455693854
# 오차 행렬
# [[ 83  87]
#  [  6 140]]
# 정확도: 0.7057, 정밀도: 0.6167, 재현율: 0.9589, F1:0.7507, AUC:0.7236
# ###########################################################################
# 임곗값: 0.2748264459999038
# 오차 행렬
# [[ 84  86]
#  [  6 140]]
# 정확도: 0.7089, 정밀도: 0.6195, 재현율: 0.9589, F1:0.7527, AUC:0.7265
# ###########################################################################
# 임곗값: 0.27970839009219556
# 오차 행렬
# [[ 86  84]
#  [  6 140]]
# 정확도: 0.7152, 정밀도: 0.6250, 재현율: 0.9589, F1:0.7568, AUC:0.7324
# ###########################################################################
# 임곗값: 0.2809787190459875
# 오차 행렬
# [[ 87  83]
#  [  6 140]]
# 정확도: 0.7184, 정밀도: 0.6278, 재현율: 0.9589, F1:0.7588, AUC:0.7353
# ###########################################################################
# 임곗값: 0.2847386296599357
# 오차 행렬
# [[ 88  82]
#  [  6 140]]
# 정확도: 0.7215, 정밀도: 0.6306, 재현율: 0.9589, F1:0.7609, AUC:0.7383
# ###########################################################################
# 임곗값: 0.2870041821470422
# 오차 행렬
# [[ 89  81]
#  [  6 140]]
# 정확도: 0.7247, 정밀도: 0.6335, 재현율: 0.9589, F1:0.7629, AUC:0.7412
# ###########################################################################
# 임곗값: 0.29052400317531446
# 오차 행렬
# [[ 90  80]
#  [  6 140]]
# 정확도: 0.7278, 정밀도: 0.6364, 재현율: 0.9589, F1:0.7650, AUC:0.7442
# ###########################################################################
# 임곗값: 0.29180448876309384
# 오차 행렬
# [[ 91  79]
#  [  6 140]]
# 정확도: 0.7310, 정밀도: 0.6393, 재현율: 0.9589, F1:0.7671, AUC:0.7471
# ###########################################################################
# 임곗값: 0.29357309735846376
# 오차 행렬
# [[ 92  78]
#  [  6 140]]
# 정확도: 0.7342, 정밀도: 0.6422, 재현율: 0.9589, F1:0.7692, AUC:0.7500
# ###########################################################################
# 임곗값: 0.29482110890052904
# 오차 행렬
# [[ 93  77]
#  [  6 140]]
# 정확도: 0.7373, 정밀도: 0.6452, 재현율: 0.9589, F1:0.7713, AUC:0.7530
# ###########################################################################
# 임곗값: 0.30240460236786737
# 오차 행렬
# [[ 95  75]
#  [  6 140]]
# 정확도: 0.7437, 정밀도: 0.6512, 재현율: 0.9589, F1:0.7756, AUC:0.7589
# ###########################################################################
# 임곗값: 0.30275152088974316
# 오차 행렬
# [[ 96  74]
#  [  6 140]]
# 정확도: 0.7468, 정밀도: 0.6542, 재현율: 0.9589, F1:0.7778, AUC:0.7618
# ###########################################################################
# 임곗값: 0.3057824961990176
# 오차 행렬
# [[ 96  74]
#  [  7 139]]
# 정확도: 0.7437, 정밀도: 0.6526, 재현율: 0.9521, F1:0.7744, AUC:0.7584
# ###########################################################################
# 임곗값: 0.3073188624338547
# 오차 행렬
# [[ 97  73]
#  [  7 139]]
# 정확도: 0.7468, 정밀도: 0.6557, 재현율: 0.9521, F1:0.7765, AUC:0.7613
# ###########################################################################
# 임곗값: 0.30900966833597854
# 오차 행렬
# [[ 97  73]
#  [  9 137]]
# 정확도: 0.7405, 정밀도: 0.6524, 재현율: 0.9384, F1:0.7697, AUC:0.7545
# ###########################################################################
# 임곗값: 0.3145526406100058
# 오차 행렬
# [[ 97  73]
#  [ 10 136]]
# 정확도: 0.7373, 정밀도: 0.6507, 재현율: 0.9315, F1:0.7662, AUC:0.7510
# ###########################################################################
# 임곗값: 0.31571136530993427
# 오차 행렬
# [[ 97  73]
#  [ 11 135]]
# 정확도: 0.7342, 정밀도: 0.6490, 재현율: 0.9247, F1:0.7627, AUC:0.7476
# ###########################################################################
# 임곗값: 0.3158426565918336
# 오차 행렬
# [[ 97  73]
#  [ 13 133]]
# 정확도: 0.7278, 정밀도: 0.6456, 재현율: 0.9110, F1:0.7557, AUC:0.7408
# ###########################################################################
# 임곗값: 0.316975361006211
# 오차 행렬
# [[ 98  72]
#  [ 13 133]]
# 정확도: 0.7310, 정밀도: 0.6488, 재현율: 0.9110, F1:0.7578, AUC:0.7437
# ###########################################################################
# 임곗값: 0.32226345421405644
# 오차 행렬
# [[ 98  72]
#  [ 14 132]]
# 정확도: 0.7278, 정밀도: 0.6471, 재현율: 0.9041, F1:0.7543, AUC:0.7403
# ###########################################################################
# 임곗값: 0.32394052045856114
# 오차 행렬
# [[ 98  72]
#  [ 16 130]]
# 정확도: 0.7215, 정밀도: 0.6436, 재현율: 0.8904, F1:0.7471, AUC:0.7334
# ###########################################################################
# 임곗값: 0.3256391786318046
# 오차 행렬
# [[ 99  71]
#  [ 16 130]]
# 정확도: 0.7247, 정밀도: 0.6468, 재현율: 0.8904, F1:0.7493, AUC:0.7364
# ###########################################################################
# 임곗값: 0.33026293041436006
# 오차 행렬
# [[100  70]
#  [ 16 130]]
# 정확도: 0.7278, 정밀도: 0.6500, 재현율: 0.8904, F1:0.7514, AUC:0.7393
# ###########################################################################
# 임곗값: 0.33217632645626277
# 오차 행렬
# [[100  70]
#  [ 17 129]]
# 정확도: 0.7247, 정밀도: 0.6482, 재현율: 0.8836, F1:0.7478, AUC:0.7359
# ###########################################################################
# 임곗값: 0.3459442703134015
# 오차 행렬
# [[101  69]
#  [ 17 129]]
# 정확도: 0.7278, 정밀도: 0.6515, 재현율: 0.8836, F1:0.7500, AUC:0.7388
# ###########################################################################
# 임곗값: 0.3464371449852787
# 오차 행렬
# [[102  68]
#  [ 17 129]]
# 정확도: 0.7310, 정밀도: 0.6548, 재현율: 0.8836, F1:0.7522, AUC:0.7418
# ###########################################################################
# 임곗값: 0.34681406592197483
# 오차 행렬
# [[104  66]
#  [ 17 129]]
# 정확도: 0.7373, 정밀도: 0.6615, 재현율: 0.8836, F1:0.7566, AUC:0.7477
# ###########################################################################
# 임곗값: 0.3471903816082042
# 오차 행렬
# [[105  65]
#  [ 17 129]]
# 정확도: 0.7405, 정밀도: 0.6649, 재현율: 0.8836, F1:0.7588, AUC:0.7506
# ###########################################################################
# 임곗값: 0.3485611747764867
# 오차 행렬
# [[107  63]
#  [ 17 129]]
# 정확도: 0.7468, 정밀도: 0.6719, 재현율: 0.8836, F1:0.7633, AUC:0.7565
# ###########################################################################
# 임곗값: 0.35564805587368437
# 오차 행렬
# [[108  62]
#  [ 17 129]]
# 정확도: 0.7500, 정밀도: 0.6754, 재현율: 0.8836, F1:0.7656, AUC:0.7594
# ###########################################################################
# 임곗값: 0.35946014655060987
# 오차 행렬
# [[108  62]
#  [ 18 128]]
# 정확도: 0.7468, 정밀도: 0.6737, 재현율: 0.8767, F1:0.7619, AUC:0.7560
# ###########################################################################
# 임곗값: 0.35992403846805876
# 오차 행렬
# [[109  61]
#  [ 18 128]]
# 정확도: 0.7500, 정밀도: 0.6772, 재현율: 0.8767, F1:0.7642, AUC:0.7589
# ###########################################################################
# 임곗값: 0.36499506694021483
# 오차 행렬
# [[109  61]
#  [ 19 127]]
# 정확도: 0.7468, 정밀도: 0.6755, 재현율: 0.8699, F1:0.7605, AUC:0.7555
# ###########################################################################
# 임곗값: 0.36546161510983305
# 오차 행렬
# [[109  61]
#  [ 20 126]]
# 정확도: 0.7437, 정밀도: 0.6738, 재현율: 0.8630, F1:0.7568, AUC:0.7521
# ###########################################################################
# 임곗값: 0.36555646170487166
# 오차 행렬
# [[110  60]
#  [ 20 126]]
# 정확도: 0.7468, 정밀도: 0.6774, 재현율: 0.8630, F1:0.7590, AUC:0.7550
# ###########################################################################
# 임곗값: 0.3703842562250343
# 오차 행렬
# [[111  59]
#  [ 20 126]]
# 정확도: 0.7500, 정밀도: 0.6811, 재현율: 0.8630, F1:0.7613, AUC:0.7580
# ###########################################################################
# 임곗값: 0.3713692315314687
# 오차 행렬
# [[112  58]
#  [ 20 126]]
# 정확도: 0.7532, 정밀도: 0.6848, 재현율: 0.8630, F1:0.7636, AUC:0.7609
# ###########################################################################
# 임곗값: 0.37693999149097784
# 오차 행렬
# [[113  57]
#  [ 20 126]]
# 정확도: 0.7563, 정밀도: 0.6885, 재현율: 0.8630, F1:0.7660, AUC:0.7639
# ###########################################################################
# 임곗값: 0.37854844856217534
# 오차 행렬
# [[114  56]
#  [ 20 126]]
# 정확도: 0.7595, 정밀도: 0.6923, 재현율: 0.8630, F1:0.7683, AUC:0.7668
# ###########################################################################
# 임곗값: 0.3798401340561505
# 오차 행렬
# [[114  56]
#  [ 21 125]]
# 정확도: 0.7563, 정밀도: 0.6906, 재현율: 0.8562, F1:0.7645, AUC:0.7634
# ###########################################################################
# 임곗값: 0.3924770392181083
# 오차 행렬
# [[115  55]
#  [ 21 125]]
# 정확도: 0.7595, 정밀도: 0.6944, 재현율: 0.8562, F1:0.7669, AUC:0.7663
# ###########################################################################
# 임곗값: 0.39473338696951443
# 오차 행렬
# [[116  54]
#  [ 21 125]]
# 정확도: 0.7627, 정밀도: 0.6983, 재현율: 0.8562, F1:0.7692, AUC:0.7693
# ###########################################################################
# 임곗값: 0.39563875340311316
# 오차 행렬
# [[116  54]
#  [ 22 124]]
# 정확도: 0.7595, 정밀도: 0.6966, 재현율: 0.8493, F1:0.7654, AUC:0.7658
# ###########################################################################
# 임곗값: 0.39789327233459076
# 오차 행렬
# [[117  53]
#  [ 22 124]]
# 정확도: 0.7627, 정밀도: 0.7006, 재현율: 0.8493, F1:0.7678, AUC:0.7688
# ###########################################################################
# 임곗값: 0.41297517027627495
# 오차 행렬
# [[117  53]
#  [ 23 123]]
# 정확도: 0.7595, 정밀도: 0.6989, 재현율: 0.8425, F1:0.7640, AUC:0.7654
# ###########################################################################
# 임곗값: 0.4175277207071526
# 오차 행렬
# [[117  53]
#  [ 24 122]]
# 정확도: 0.7563, 정밀도: 0.6971, 재현율: 0.8356, F1:0.7601, AUC:0.7619
# ###########################################################################
# 임곗값: 0.4178286506401417
# 오차 행렬
# [[117  53]
#  [ 25 121]]
# 정확도: 0.7532, 정밀도: 0.6954, 재현율: 0.8288, F1:0.7563, AUC:0.7585
# ###########################################################################
# 임곗값: 0.4190883795788426
# 오차 행렬
# [[119  51]
#  [ 25 121]]
# 정확도: 0.7595, 정밀도: 0.7035, 재현율: 0.8288, F1:0.7610, AUC:0.7644
# ###########################################################################
# 임곗값: 0.4198521895292399
# 오차 행렬
# [[120  50]
#  [ 25 121]]
# 정확도: 0.7627, 정밀도: 0.7076, 재현율: 0.8288, F1:0.7634, AUC:0.7673
# ###########################################################################
# 임곗값: 0.4252295293686337
# 오차 행렬
# [[121  49]
#  [ 25 121]]
# 정확도: 0.7658, 정밀도: 0.7118, 재현율: 0.8288, F1:0.7658, AUC:0.7703
# ###########################################################################
# 임곗값: 0.4263362234454471
# 오차 행렬
# [[123  47]
#  [ 25 121]]
# 정확도: 0.7722, 정밀도: 0.7202, 재현율: 0.8288, F1:0.7707, AUC:0.7761
# ###########################################################################
# 임곗값: 0.42832717053945046
# 오차 행렬
# [[123  47]
#  [ 26 120]]
# 정확도: 0.7690, 정밀도: 0.7186, 재현율: 0.8219, F1:0.7668, AUC:0.7727
# ###########################################################################
# 임곗값: 0.4287409359902852
# 오차 행렬
# [[124  46]
#  [ 26 120]]
# 정확도: 0.7722, 정밀도: 0.7229, 재현율: 0.8219, F1:0.7692, AUC:0.7757
# ###########################################################################
# 임곗값: 0.4362029619469565
# 오차 행렬
# [[126  44]
#  [ 26 120]]
# 정확도: 0.7785, 정밀도: 0.7317, 재현율: 0.8219, F1:0.7742, AUC:0.7815
# ###########################################################################
# 임곗값: 0.4373489000101493
# 오차 행렬
# [[127  43]
#  [ 26 120]]
# 정확도: 0.7816, 정밀도: 0.7362, 재현율: 0.8219, F1:0.7767, AUC:0.7845
# ###########################################################################
# 임곗값: 0.439640034097232
# 오차 행렬
# [[129  41]
#  [ 26 120]]
# 정확도: 0.7880, 정밀도: 0.7453, 재현율: 0.8219, F1:0.7818, AUC:0.7904
# ###########################################################################
# 임곗값: 0.4404001236194306
# 오차 행렬
# [[129  41]
#  [ 27 119]]
# 정확도: 0.7848, 정밀도: 0.7438, 재현율: 0.8151, F1:0.7778, AUC:0.7869
# ###########################################################################
# 임곗값: 0.44248272581148107
# 오차 행렬
# [[131  39]
#  [ 27 119]]
# 정확도: 0.7911, 정밀도: 0.7532, 재현율: 0.8151, F1:0.7829, AUC:0.7928
# ###########################################################################
# 임곗값: 0.4445343720837647
# 오차 행렬
# [[132  38]
#  [ 27 119]]
# 정확도: 0.7943, 정밀도: 0.7580, 재현율: 0.8151, F1:0.7855, AUC:0.7958
# ###########################################################################
# 임곗값: 0.45125098516281736
# 오차 행렬
# [[133  37]
#  [ 27 119]]
# 정확도: 0.7975, 정밀도: 0.7628, 재현율: 0.8151, F1:0.7881, AUC:0.7987
# ###########################################################################
# 임곗값: 0.45357718499165633
# 오차 행렬
# [[133  37]
#  [ 28 118]]
# 정확도: 0.7943, 정밀도: 0.7613, 재현율: 0.8082, F1:0.7841, AUC:0.7953
# ###########################################################################
# 임곗값: 0.4542609873402508
# 오차 행렬
# [[135  35]
#  [ 28 118]]
# 정확도: 0.8006, 정밀도: 0.7712, 재현율: 0.8082, F1:0.7893, AUC:0.8012
# ###########################################################################
# 임곗값: 0.45512107042853733
# 오차 행렬
# [[136  34]
#  [ 28 118]]
# 정확도: 0.8038, 정밀도: 0.7763, 재현율: 0.8082, F1:0.7919, AUC:0.8041
# ###########################################################################
# 임곗값: 0.45864963306346873
# 오차 행렬
# [[136  34]
#  [ 30 116]]
# 정확도: 0.7975, 정밀도: 0.7733, 재현율: 0.7945, F1:0.7838, AUC:0.7973
# ###########################################################################
# 임곗값: 0.46275921726570723
# 오차 행렬
# [[136  34]
#  [ 31 115]]
# 정확도: 0.7943, 정밀도: 0.7718, 재현율: 0.7877, F1:0.7797, AUC:0.7938
# ###########################################################################
# 임곗값: 0.46653050898265336
# 오차 행렬
# [[136  34]
#  [ 32 114]]
# 정확도: 0.7911, 정밀도: 0.7703, 재현율: 0.7808, F1:0.7755, AUC:0.7904
# ###########################################################################
# 임곗값: 0.46952857003097626
# 오차 행렬
# [[137  33]
#  [ 32 114]]
# 정확도: 0.7943, 정밀도: 0.7755, 재현율: 0.7808, F1:0.7782, AUC:0.7934
# ###########################################################################
# 임곗값: 0.4727309803525027
# 오차 행렬
# [[138  32]
#  [ 32 114]]
# 정확도: 0.7975, 정밀도: 0.7808, 재현율: 0.7808, F1:0.7808, AUC:0.7963
# ###########################################################################
# 임곗값: 0.4732675433730755
# 오차 행렬
# [[139  31]
#  [ 32 114]]
# 정확도: 0.8006, 정밀도: 0.7862, 재현율: 0.7808, F1:0.7835, AUC:0.7992
# ###########################################################################
# 임곗값: 0.48689266849927243
# 오차 행렬
# [[140  30]
#  [ 32 114]]
# 정확도: 0.8038, 정밀도: 0.7917, 재현율: 0.7808, F1:0.7862, AUC:0.8022
# ###########################################################################
# 임곗값: 0.48758343055382286
# 오차 행렬
# [[140  30]
#  [ 33 113]]
# 정확도: 0.8006, 정밀도: 0.7902, 재현율: 0.7740, F1:0.7820, AUC:0.7988
# ###########################################################################
# 임곗값: 0.4921219567944666
# 오차 행렬
# [[140  30]
#  [ 34 112]]
# 정확도: 0.7975, 정밀도: 0.7887, 재현율: 0.7671, F1:0.7778, AUC:0.7953
# ###########################################################################
# 임곗값: 0.4966871908577706
# 오차 행렬
# [[140  30]
#  [ 35 111]]
# 정확도: 0.7943, 정밀도: 0.7872, 재현율: 0.7603, F1:0.7735, AUC:0.7919
# ###########################################################################
# 임곗값: 0.5026101234381973
# 오차 행렬
# [[140  30]
#  [ 37 109]]
# 정확도: 0.7880, 정밀도: 0.7842, 재현율: 0.7466, F1:0.7649, AUC:0.7851
# ###########################################################################
# 임곗값: 0.5060677982033297
# 오차 행렬
# [[140  30]
#  [ 38 108]]
# 정확도: 0.7848, 정밀도: 0.7826, 재현율: 0.7397, F1:0.7606, AUC:0.7816
# ###########################################################################
# 임곗값: 0.5115044946046087
# 오차 행렬
# [[140  30]
#  [ 39 107]]
# 정확도: 0.7816, 정밀도: 0.7810, 재현율: 0.7329, F1:0.7562, AUC:0.7782
# ###########################################################################
# 임곗값: 0.5164139816802077
# 오차 행렬
# [[140  30]
#  [ 41 105]]
# 정확도: 0.7753, 정밀도: 0.7778, 재현율: 0.7192, F1:0.7473, AUC:0.7714
# ###########################################################################
# 임곗값: 0.5174481022420782
# 오차 행렬
# [[140  30]
#  [ 42 104]]
# 정확도: 0.7722, 정밀도: 0.7761, 재현율: 0.7123, F1:0.7429, AUC:0.7679
# ###########################################################################
# 임곗값: 0.5229986147465998
# 오차 행렬
# [[141  29]
#  [ 42 104]]
# 정확도: 0.7753, 정밀도: 0.7820, 재현율: 0.7123, F1:0.7455, AUC:0.7709
# ###########################################################################
# 임곗값: 0.5242398209533367
# 오차 행렬
# [[141  29]
#  [ 43 103]]
# 정확도: 0.7722, 정밀도: 0.7803, 재현율: 0.7055, F1:0.7410, AUC:0.7674
# ###########################################################################
# 임곗값: 0.5271132700944743
# 오차 행렬
# [[141  29]
#  [ 45 101]]
# 정확도: 0.7658, 정밀도: 0.7769, 재현율: 0.6918, F1:0.7319, AUC:0.7606
# ###########################################################################
# 임곗값: 0.5281137901823606
# 오차 행렬
# [[142  28]
#  [ 45 101]]
# 정확도: 0.7690, 정밀도: 0.7829, 재현율: 0.6918, F1:0.7345, AUC:0.7635
# ###########################################################################
# 임곗값: 0.5357970921200244
# 오차 행렬
# [[142  28]
#  [ 46 100]]
# 정확도: 0.7658, 정밀도: 0.7812, 재현율: 0.6849, F1:0.7299, AUC:0.7601
# ###########################################################################
# 임곗값: 0.5371953640839814
# 오차 행렬
# [[142  28]
#  [ 47  99]]
# 정확도: 0.7627, 정밀도: 0.7795, 재현율: 0.6781, F1:0.7253, AUC:0.7567
# ###########################################################################
# 임곗값: 0.5438326105496701
# 오차 행렬
# [[143  27]
#  [ 47  99]]
# 정확도: 0.7658, 정밀도: 0.7857, 재현율: 0.6781, F1:0.7279, AUC:0.7596
# ###########################################################################
# 임곗값: 0.544652788293957
# 오차 행렬
# [[143  27]
#  [ 48  98]]
# 정확도: 0.7627, 정밀도: 0.7840, 재현율: 0.6712, F1:0.7232, AUC:0.7562
# ###########################################################################
# 임곗값: 0.5522605676344192
# 오차 행렬
# [[143  27]
#  [ 49  97]]
# 정확도: 0.7595, 정밀도: 0.7823, 재현율: 0.6644, F1:0.7185, AUC:0.7528
# ###########################################################################
# 임곗값: 0.5523277829350594
# 오차 행렬
# [[143  27]
#  [ 50  96]]
# 정확도: 0.7563, 정밀도: 0.7805, 재현율: 0.6575, F1:0.7138, AUC:0.7494
# ###########################################################################
# 임곗값: 0.5525876781314195
# 오차 행렬
# [[143  27]
#  [ 51  95]]
# 정확도: 0.7532, 정밀도: 0.7787, 재현율: 0.6507, F1:0.7090, AUC:0.7459
# ###########################################################################
# 임곗값: 0.5542457682389303
# 오차 행렬
# [[144  26]
#  [ 51  95]]
# 정확도: 0.7563, 정밀도: 0.7851, 재현율: 0.6507, F1:0.7116, AUC:0.7489
# ###########################################################################
# 임곗값: 0.5570065968267398
# 오차 행렬
# [[144  26]
#  [ 52  94]]
# 정확도: 0.7532, 정밀도: 0.7833, 재현율: 0.6438, F1:0.7068, AUC:0.7454
# ###########################################################################
# 임곗값: 0.5605077905539474
# 오차 행렬
# [[144  26]
#  [ 53  93]]
# 정확도: 0.7500, 정밀도: 0.7815, 재현율: 0.6370, F1:0.7019, AUC:0.7420
# ###########################################################################
# 임곗값: 0.5616800295632143
# 오차 행렬
# [[144  26]
#  [ 54  92]]
# 정확도: 0.7468, 정밀도: 0.7797, 재현율: 0.6301, F1:0.6970, AUC:0.7386
# ###########################################################################
# 임곗값: 0.5658434623521024
# 오차 행렬
# [[145  25]
#  [ 54  92]]
# 정확도: 0.7500, 정밀도: 0.7863, 재현율: 0.6301, F1:0.6996, AUC:0.7415
# ###########################################################################
# 임곗값: 0.5700373747176157
# 오차 행렬
# [[146  24]
#  [ 54  92]]
# 정확도: 0.7532, 정밀도: 0.7931, 재현율: 0.6301, F1:0.7023, AUC:0.7445
# ###########################################################################
# 임곗값: 0.5764005280627449
# 오차 행렬
# [[147  23]
#  [ 54  92]]
# 정확도: 0.7563, 정밀도: 0.8000, 재현율: 0.6301, F1:0.7050, AUC:0.7474
# ###########################################################################
# 임곗값: 0.5774438607048987
# 오차 행렬
# [[148  22]
#  [ 54  92]]
# 정확도: 0.7595, 정밀도: 0.8070, 재현율: 0.6301, F1:0.7077, AUC:0.7504
# ###########################################################################
# 임곗값: 0.5791326811611944
# 오차 행렬
# [[148  22]
#  [ 56  90]]
# 정확도: 0.7532, 정밀도: 0.8036, 재현율: 0.6164, F1:0.6977, AUC:0.7435
# ###########################################################################
# 임곗값: 0.5839752090034479
# 오차 행렬
# [[149  21]
#  [ 56  90]]
# 정확도: 0.7563, 정밀도: 0.8108, 재현율: 0.6164, F1:0.7004, AUC:0.7465
# ###########################################################################
# 임곗값: 0.5915015661365921
# 오차 행렬
# [[149  21]
#  [ 57  89]]
# 정확도: 0.7532, 정밀도: 0.8091, 재현율: 0.6096, F1:0.6953, AUC:0.7430
# ###########################################################################
# 임곗값: 0.5939769037275461
# 오차 행렬
# [[150  20]
#  [ 57  89]]
# 정확도: 0.7563, 정밀도: 0.8165, 재현율: 0.6096, F1:0.6980, AUC:0.7460
# ###########################################################################
# 임곗값: 0.5951461950001544
# 오차 행렬
# [[150  20]
#  [ 58  88]]
# 정확도: 0.7532, 정밀도: 0.8148, 재현율: 0.6027, F1:0.6929, AUC:0.7425
# ###########################################################################
# 임곗값: 0.6058064833653091
# 오차 행렬
# [[150  20]
#  [ 60  86]]
# 정확도: 0.7468, 정밀도: 0.8113, 재현율: 0.5890, F1:0.6825, AUC:0.7357
# ###########################################################################
# 임곗값: 0.6114834450710761
# 오차 행렬
# [[151  19]
#  [ 60  86]]
# 정확도: 0.7500, 정밀도: 0.8190, 재현율: 0.5890, F1:0.6853, AUC:0.7386
# ###########################################################################
# 임곗값: 0.6125463570869545
# 오차 행렬
# [[152  18]
#  [ 60  86]]
# 정확도: 0.7532, 정밀도: 0.8269, 재현율: 0.5890, F1:0.6880, AUC:0.7416
# ###########################################################################
# 임곗값: 0.6143178680572551
# 오차 행렬
# [[152  18]
#  [ 62  84]]
# 정확도: 0.7468, 정밀도: 0.8235, 재현율: 0.5753, F1:0.6774, AUC:0.7347
# ###########################################################################
# 임곗값: 0.6144204112589535
# 오차 행렬
# [[153  17]
#  [ 62  84]]
# 정확도: 0.7500, 정밀도: 0.8317, 재현율: 0.5753, F1:0.6802, AUC:0.7377
# ###########################################################################
# 임곗값: 0.6217757939358434
# 오차 행렬
# [[154  16]
#  [ 62  84]]
# 정확도: 0.7532, 정밀도: 0.8400, 재현율: 0.5753, F1:0.6829, AUC:0.7406
# ###########################################################################
# 임곗값: 0.6410433428734925
# 오차 행렬
# [[155  15]
#  [ 62  84]]
# 정확도: 0.7563, 정밀도: 0.8485, 재현율: 0.5753, F1:0.6857, AUC:0.7436
# ###########################################################################
# 임곗값: 0.6447147500408474
# 오차 행렬
# [[156  14]
#  [ 62  84]]
# 정확도: 0.7595, 정밀도: 0.8571, 재현율: 0.5753, F1:0.6885, AUC:0.7465
# ###########################################################################
# 임곗값: 0.6550127508093065
# 오차 행렬
# [[156  14]
#  [ 64  82]]
# 정확도: 0.7532, 정밀도: 0.8542, 재현율: 0.5616, F1:0.6777, AUC:0.7396
# ###########################################################################
# 임곗값: 0.6577801644601373
# 오차 행렬
# [[157  13]
#  [ 64  82]]
# 정확도: 0.7563, 정밀도: 0.8632, 재현율: 0.5616, F1:0.6805, AUC:0.7426
# ###########################################################################
# 임곗값: 0.661550372056555
# 오차 행렬
# [[157  13]
#  [ 66  80]]
# 정확도: 0.7500, 정밀도: 0.8602, 재현율: 0.5479, F1:0.6695, AUC:0.7357
# ###########################################################################
# 임곗값: 0.662437132232237
# 오차 행렬
# [[157  13]
#  [ 67  79]]
# 정확도: 0.7468, 정밀도: 0.8587, 재현율: 0.5411, F1:0.6639, AUC:0.7323
# ###########################################################################
# 임곗값: 0.6661617442006447
# 오차 행렬
# [[157  13]
#  [ 69  77]]
# 정확도: 0.7405, 정밀도: 0.8556, 재현율: 0.5274, F1:0.6525, AUC:0.7255
# ###########################################################################
# 임곗값: 0.6726300938361365
# 오차 행렬
# [[158  12]
#  [ 69  77]]
# 정확도: 0.7437, 정밀도: 0.8652, 재현율: 0.5274, F1:0.6553, AUC:0.7284
# ###########################################################################
# 임곗값: 0.675529234057952
# 오차 행렬
# [[158  12]
#  [ 70  76]]
# 정확도: 0.7405, 정밀도: 0.8636, 재현율: 0.5205, F1:0.6496, AUC:0.7250
# ###########################################################################
# 임곗값: 0.685420514039286
# 오차 행렬
# [[159  11]
#  [ 70  76]]
# 정확도: 0.7437, 정밀도: 0.8736, 재현율: 0.5205, F1:0.6524, AUC:0.7279
# ###########################################################################
# 임곗값: 0.6959290036920801
# 오차 행렬
# [[159  11]
#  [ 72  74]]
# 정확도: 0.7373, 정밀도: 0.8706, 재현율: 0.5068, F1:0.6407, AUC:0.7211
# ###########################################################################
# 임곗값: 0.7086806353150958
# 오차 행렬
# [[160  10]
#  [ 72  74]]
# 정확도: 0.7405, 정밀도: 0.8810, 재현율: 0.5068, F1:0.6435, AUC:0.7240
# ###########################################################################
# 임곗값: 0.7105875789837475
# 오차 행렬
# [[160  10]
#  [ 73  73]]
# 정확도: 0.7373, 정밀도: 0.8795, 재현율: 0.5000, F1:0.6376, AUC:0.7206
# ###########################################################################
# 임곗값: 0.7106065332169518
# 오차 행렬
# [[160  10]
#  [ 75  71]]
# 정확도: 0.7310, 정밀도: 0.8765, 재현율: 0.4863, F1:0.6256, AUC:0.7137
# ###########################################################################
# 임곗값: 0.7146870295319177
# 오차 행렬
# [[160  10]
#  [ 77  69]]
# 정확도: 0.7247, 정밀도: 0.8734, 재현율: 0.4726, F1:0.6133, AUC:0.7069
# ###########################################################################
# 임곗값: 0.7215293325577926
# 오차 행렬
# [[160  10]
#  [ 79  67]]
# 정확도: 0.7184, 정밀도: 0.8701, 재현율: 0.4589, F1:0.6009, AUC:0.7000
# ###########################################################################
# 임곗값: 0.7311564683228637
# 오차 행렬
# [[160  10]
#  [ 80  66]]
# 정확도: 0.7152, 정밀도: 0.8684, 재현율: 0.4521, F1:0.5946, AUC:0.6966
# ###########################################################################
# 임곗값: 0.7352873355424626
# 오차 행렬
# [[160  10]
#  [ 81  65]]
# 정확도: 0.7120, 정밀도: 0.8667, 재현율: 0.4452, F1:0.5882, AUC:0.6932
# ###########################################################################
# 임곗값: 0.7407769528678327
# 오차 행렬
# [[160  10]
#  [ 85  61]]
# 정확도: 0.6994, 정밀도: 0.8592, 재현율: 0.4178, F1:0.5622, AUC:0.6795
# ###########################################################################
# 임곗값: 0.7420653482202249
# 오차 행렬
# [[161   9]
#  [ 85  61]]
# 정확도: 0.7025, 정밀도: 0.8714, 재현율: 0.4178, F1:0.5648, AUC:0.6824
# ###########################################################################
# 임곗값: 0.7650631544617595
# 오차 행렬
# [[161   9]
#  [ 86  60]]
# 정확도: 0.6994, 정밀도: 0.8696, 재현율: 0.4110, F1:0.5581, AUC:0.6790
# ###########################################################################
# 임곗값: 0.7780630335288264
# 오차 행렬
# [[161   9]
#  [ 89  57]]
# 정확도: 0.6899, 정밀도: 0.8636, 재현율: 0.3904, F1:0.5377, AUC:0.6687
# ###########################################################################
# 임곗값: 0.778160865415543
# 오차 행렬
# [[162   8]
#  [ 89  57]]
# 정확도: 0.6930, 정밀도: 0.8769, 재현율: 0.3904, F1:0.5403, AUC:0.6717
# ###########################################################################
# 임곗값: 0.7800953562962047
# 오차 행렬
# [[162   8]
#  [ 90  56]]
# 정확도: 0.6899, 정밀도: 0.8750, 재현율: 0.3836, F1:0.5333, AUC:0.6683
# ###########################################################################
# 임곗값: 0.7839609715193487
# 오차 행렬
# [[162   8]
#  [ 91  55]]
# 정확도: 0.6867, 정밀도: 0.8730, 재현율: 0.3767, F1:0.5263, AUC:0.6648
# ###########################################################################
# 임곗값: 0.7840527636720295
# 오차 행렬
# [[162   8]
#  [ 93  53]]
# 정확도: 0.6804, 정밀도: 0.8689, 재현율: 0.3630, F1:0.5121, AUC:0.6580
# ###########################################################################
# 임곗값: 0.7842931503311331
# 오차 행렬
# [[162   8]
#  [ 94  52]]
# 정확도: 0.6772, 정밀도: 0.8667, 재현율: 0.3562, F1:0.5049, AUC:0.6546
# ###########################################################################
# 임곗값: 0.7869472816988918
# 오차 행렬
# [[164   6]
#  [ 94  52]]
# 정확도: 0.6835, 정밀도: 0.8966, 재현율: 0.3562, F1:0.5098, AUC:0.6604
# ###########################################################################
# 임곗값: 0.7923886574011516
# 오차 행렬
# [[164   6]
#  [ 95  51]]
# 정확도: 0.6804, 정밀도: 0.8947, 재현율: 0.3493, F1:0.5025, AUC:0.6570
# ###########################################################################
# 임곗값: 0.8065389686658546
# 오차 행렬
# [[164   6]
#  [ 96  50]]
# 정확도: 0.6772, 정밀도: 0.8929, 재현율: 0.3425, F1:0.4950, AUC:0.6536
# ###########################################################################
# 임곗값: 0.8078932570748366
# 오차 행렬
# [[165   5]
#  [ 96  50]]
# 정확도: 0.6804, 정밀도: 0.9091, 재현율: 0.3425, F1:0.4975, AUC:0.6565
# ###########################################################################
# 임곗값: 0.8107908190472534
# 오차 행렬
# [[165   5]
#  [ 97  49]]
# 정확도: 0.6772, 정밀도: 0.9074, 재현율: 0.3356, F1:0.4900, AUC:0.6531
# ###########################################################################
# 임곗값: 0.8109608822433586
# 오차 행렬
# [[165   5]
#  [ 98  48]]
# 정확도: 0.6741, 정밀도: 0.9057, 재현율: 0.3288, F1:0.4824, AUC:0.6497
# ###########################################################################
# 임곗값: 0.8238126196492003
# 오차 행렬
# [[165   5]
#  [ 99  47]]
# 정확도: 0.6709, 정밀도: 0.9038, 재현율: 0.3219, F1:0.4747, AUC:0.6463
# ###########################################################################
# 임곗값: 0.8272355417345574
# 오차 행렬
# [[165   5]
#  [100  46]]
# 정확도: 0.6677, 정밀도: 0.9020, 재현율: 0.3151, F1:0.4670, AUC:0.6428
# ###########################################################################
# 임곗값: 0.8287905619450967
# 오차 행렬
# [[165   5]
#  [102  44]]
# 정확도: 0.6614, 정밀도: 0.8980, 재현율: 0.3014, F1:0.4513, AUC:0.6360
# ###########################################################################
# 임곗값: 0.8322535946416993
# 오차 행렬
# [[165   5]
#  [103  43]]
# 정확도: 0.6582, 정밀도: 0.8958, 재현율: 0.2945, F1:0.4433, AUC:0.6326
# ###########################################################################
# 임곗값: 0.8409996077360937
# 오차 행렬
# [[166   4]
#  [103  43]]
# 정확도: 0.6614, 정밀도: 0.9149, 재현율: 0.2945, F1:0.4456, AUC:0.6355
# ###########################################################################
# 임곗값: 0.8463196120181499
# 오차 행렬
# [[166   4]
#  [105  41]]
# 정확도: 0.6551, 정밀도: 0.9111, 재현율: 0.2808, F1:0.4293, AUC:0.6286
# ###########################################################################
# 임곗값: 0.8470010079531297
# 오차 행렬
# [[166   4]
#  [106  40]]
# 정확도: 0.6519, 정밀도: 0.9091, 재현율: 0.2740, F1:0.4211, AUC:0.6252
# ###########################################################################
# 임곗값: 0.847591017054924
# 오차 행렬
# [[166   4]
#  [109  37]]
# 정확도: 0.6424, 정밀도: 0.9024, 재현율: 0.2534, F1:0.3957, AUC:0.6149
# ###########################################################################
# 임곗값: 0.8484607891099568
# 오차 행렬
# [[166   4]
#  [112  34]]
# 정확도: 0.6329, 정밀도: 0.8947, 재현율: 0.2329, F1:0.3696, AUC:0.6047
# ###########################################################################
# 임곗값: 0.8486492884072792
# 오차 행렬
# [[166   4]
#  [113  33]]
# 정확도: 0.6297, 정밀도: 0.8919, 재현율: 0.2260, F1:0.3607, AUC:0.6012
# ###########################################################################
# 임곗값: 0.8492140342107015
# 오차 행렬
# [[167   3]
#  [113  33]]
# 정확도: 0.6329, 정밀도: 0.9167, 재현율: 0.2260, F1:0.3626, AUC:0.6042
# ###########################################################################
# 임곗값: 0.8492513196404691
# 오차 행렬
# [[168   2]
#  [113  33]]
# 정확도: 0.6361, 정밀도: 0.9429, 재현율: 0.2260, F1:0.3646, AUC:0.6071
# ###########################################################################
# 임곗값: 0.8504343674312866
# 오차 행렬
# [[168   2]
#  [114  32]]
# 정확도: 0.6329, 정밀도: 0.9412, 재현율: 0.2192, F1:0.3556, AUC:0.6037
# ###########################################################################
# 임곗값: 0.8512361103769847
# 오차 행렬
# [[168   2]
#  [115  31]]
# 정확도: 0.6297, 정밀도: 0.9394, 재현율: 0.2123, F1:0.3464, AUC:0.6003
# ###########################################################################
# 임곗값: 0.8530030476552802
# 오차 행렬
# [[168   2]
#  [117  29]]
# 정확도: 0.6234, 정밀도: 0.9355, 재현율: 0.1986, F1:0.3277, AUC:0.5934
# ###########################################################################
# 임곗값: 0.854868285255134
# 오차 행렬
# [[168   2]
#  [118  28]]
# 정확도: 0.6203, 정밀도: 0.9333, 재현율: 0.1918, F1:0.3182, AUC:0.5900
# ###########################################################################
# 임곗값: 0.8618951728247791
# 오차 행렬
# [[168   2]
#  [120  26]]
# 정확도: 0.6139, 정밀도: 0.9286, 재현율: 0.1781, F1:0.2989, AUC:0.5832
# ###########################################################################
# 임곗값: 0.8651086802397344
# 오차 행렬
# [[168   2]
#  [122  24]]
# 정확도: 0.6076, 정밀도: 0.9231, 재현율: 0.1644, F1:0.2791, AUC:0.5763
# ###########################################################################
# 임곗값: 0.8661337781286057
# 오차 행렬
# [[168   2]
#  [123  23]]
# 정확도: 0.6044, 정밀도: 0.9200, 재현율: 0.1575, F1:0.2690, AUC:0.5729
# ###########################################################################
# 임곗값: 0.8663495747839632
# 오차 행렬
# [[168   2]
#  [124  22]]
# 정확도: 0.6013, 정밀도: 0.9167, 재현율: 0.1507, F1:0.2588, AUC:0.5695
# ###########################################################################
# 임곗값: 0.8668191152762421
# 오차 행렬
# [[168   2]
#  [126  20]]
# 정확도: 0.5949, 정밀도: 0.9091, 재현율: 0.1370, F1:0.2381, AUC:0.5626
# ###########################################################################
# 임곗값: 0.8727622402466205
# 오차 행렬
# [[169   1]
#  [126  20]]
# 정확도: 0.5981, 정밀도: 0.9524, 재현율: 0.1370, F1:0.2395, AUC:0.5656
# ###########################################################################
# 임곗값: 0.875650779818715
# 오차 행렬
# [[169   1]
#  [127  19]]
# 정확도: 0.5949, 정밀도: 0.9500, 재현율: 0.1301, F1:0.2289, AUC:0.5621
# ###########################################################################
# 임곗값: 0.8771389599708715
# 오차 행렬
# [[169   1]
#  [128  18]]
# 정확도: 0.5918, 정밀도: 0.9474, 재현율: 0.1233, F1:0.2182, AUC:0.5587
# ###########################################################################
# 임곗값: 0.8865927260474473
# 오차 행렬
# [[169   1]
#  [129  17]]
# 정확도: 0.5886, 정밀도: 0.9444, 재현율: 0.1164, F1:0.2073, AUC:0.5553
# ###########################################################################
# 임곗값: 0.888532095684328
# 오차 행렬
# [[169   1]
#  [130  16]]
# 정확도: 0.5854, 정밀도: 0.9412, 재현율: 0.1096, F1:0.1963, AUC:0.5519
# ###########################################################################
# 임곗값: 0.9031506115962226
# 오차 행렬
# [[169   1]
#  [131  15]]
# 정확도: 0.5823, 정밀도: 0.9375, 재현율: 0.1027, F1:0.1852, AUC:0.5484
# ###########################################################################
# 임곗값: 0.9043823329225019
# 오차 행렬
# [[169   1]
#  [132  14]]
# 정확도: 0.5791, 정밀도: 0.9333, 재현율: 0.0959, F1:0.1739, AUC:0.5450
# ###########################################################################
# 임곗값: 0.9079059777813189
# 오차 행렬
# [[169   1]
#  [133  13]]
# 정확도: 0.5759, 정밀도: 0.9286, 재현율: 0.0890, F1:0.1625, AUC:0.5416
# ###########################################################################
# 임곗값: 0.9131254148272628
# 오차 행렬
# [[169   1]
#  [134  12]]
# 정확도: 0.5728, 정밀도: 0.9231, 재현율: 0.0822, F1:0.1509, AUC:0.5382
# ###########################################################################
# 임곗값: 0.92088788692571
# 오차 행렬
# [[169   1]
#  [135  11]]
# 정확도: 0.5696, 정밀도: 0.9167, 재현율: 0.0753, F1:0.1392, AUC:0.5347
# ###########################################################################
# 임곗값: 0.9238194130884819
# 오차 행렬
# [[169   1]
#  [137   9]]
# 정확도: 0.5633, 정밀도: 0.9000, 재현율: 0.0616, F1:0.1154, AUC:0.5279
# ###########################################################################
# 임곗값: 0.9284840206364023
# 오차 행렬
# [[170   0]
#  [137   9]]
# 정확도: 0.5665, 정밀도: 1.0000, 재현율: 0.0616, F1:0.1161, AUC:0.5308
# ###########################################################################
# 임곗값: 0.9304964488383548
# 오차 행렬
# [[170   0]
#  [138   8]]
# 정확도: 0.5633, 정밀도: 1.0000, 재현율: 0.0548, F1:0.1039, AUC:0.5274
# ###########################################################################
# 임곗값: 0.9322646606330005
# 오차 행렬
# [[170   0]
#  [139   7]]
# 정확도: 0.5601, 정밀도: 1.0000, 재현율: 0.0479, F1:0.0915, AUC:0.5240
# ###########################################################################
# 임곗값: 0.9378637066548159
# 오차 행렬
# [[170   0]
#  [140   6]]
# 정확도: 0.5570, 정밀도: 1.0000, 재현율: 0.0411, F1:0.0789, AUC:0.5205
# ###########################################################################
# 임곗값: 0.9402858931336339
# 오차 행렬
# [[170   0]
#  [141   5]]
# 정확도: 0.5538, 정밀도: 1.0000, 재현율: 0.0342, F1:0.0662, AUC:0.5171
# ###########################################################################
# 임곗값: 0.949381379466826
# 오차 행렬
# [[170   0]
#  [142   4]]
# 정확도: 0.5506, 정밀도: 1.0000, 재현율: 0.0274, F1:0.0533, AUC:0.5137
# ###########################################################################
# 임곗값: 0.9512111542896555
# 오차 행렬
# [[170   0]
#  [143   3]]
# 정확도: 0.5475, 정밀도: 1.0000, 재현율: 0.0205, F1:0.0403, AUC:0.5103
# ###########################################################################
# 임곗값: 0.9677446819537107
# 오차 행렬
# [[170   0]
#  [145   1]]
# 정확도: 0.5411, 정밀도: 1.0000, 재현율: 0.0068, F1:0.0136, AUC:0.5034
# ###########################################################################
# 임곗값: 0.9803247348046857
# 오차 행렬
# [[170   0]
#  [146   0]]
# 정확도: 0.5380, 정밀도: 0.0000, 재현율: 0.0000, F1:0.0000, AUC:0.5000
# ###########################################################################
# C:\Users\LEGION\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# - **임계값 조정**
# 임곗값: 0.45512107042853733
# 오차 행렬
# [[136  34]
#  [ 28 118]]
# **정확도: 0.8038, 정밀도: 0.7763, 재현율: 0.8082, F1:0.7919, AUC:0.8041**

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

# 타겟 데이터와 예측 객체를 전달받는다.
def get_evaluation_by_custom_proba(y_test, prediction, visualize=False):
#     오차 행렬
    confusion = confusion_matrix(y_test, prediction)
#     정확도
    accuracy = accuracy_score(y_test , prediction)
#     정밀도
    precision = precision_score(y_test , prediction)
#     재현율
    recall = recall_score(y_test , prediction)
#     F1 score
    f1 = f1_score(y_test, prediction)
#     ROC-AUC
    roc_auc = roc_auc_score(y_test, prediction)
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, ROC-AUC: {4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))
    print("#" * 80)
    
    if visualize:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_predictions(y_test, prediction, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
binarizer = Binarizer(threshold=0.455)
custom_prediction = binarizer.fit_transform(lg.predict_proba(X_test)[:, 1].reshape(-1, 1))
get_evaluation_by_custom_proba(y_test, custom_prediction, True)
# Out:
# 오차 행렬
# [[135  35]
#  [ 28 118]]
# 정확도: 0.8006, 정밀도: 0.7712, 재현율: 0.8082, F1: 0.7893, ROC-AUC: 0.8012
# ################################################################################

# %%
data = {
    'model': ['9Cycle', '10Cycle'],
    '정확도': [0.7943, 0.8006],
    '정밀도': [0.7872, 0.7712],
    '재현율': [0.7603, 0.8082],
    'F1': [0.7735, 0.7893],
    'AUC': [0.7919, 0.8012]
}

Cycle10 = pd.DataFrame(data)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 프레임에서 각 모델명과 해당 지표들을 추출합니다.
models = Cycle10['model']
accuracy = Cycle10['정확도']
precision = Cycle10['정밀도']
recall = Cycle10['재현율']
f1 = Cycle10['F1']
AUC = Cycle10['AUC']

# 그래프를 그립니다.
bar_width = 0.2
index = np.arange(len(models))

# 컬러맵 가져오기
cmap = plt.get_cmap('Pastel1')

plt.figure(figsize=(12, 6))

plt.bar(index, accuracy, color=cmap(np.array([0])), width=bar_width, label='정확도', edgecolor='black')
plt.bar(index + bar_width, precision, color=cmap(np.array([1])), width=bar_width, label='정밀도', edgecolor='black')
plt.bar(index + 2*bar_width, recall, color=cmap(np.array([2])), width=bar_width, label='재현율', edgecolor='black')
plt.bar(index + 3*bar_width, f1, color=cmap(np.array([3])), width=bar_width, label='F1', edgecolor='black')
# plt.bar(index + 4*bar_width, AUC, color=cmap(np.array([4])), width=bar_width, label='AUC', edgecolor='black')

plt.title('각 모델의 성능 비교', fontsize=16)
plt.xlabel('모델', fontsize=14)
plt.ylabel('성능', fontsize=14)
plt.xticks(index + bar_width, models, rotation=45, ha='right')
plt.legend()
plt.grid(True)

# y축의 범위 지정
plt.ylim(0.75, 0.82)

plt.tight_layout()
plt.show()

display(Cycle10)
# Out:
#      model     정확도     정밀도     재현율      F1     AUC
# 0   9Cycle  0.7943  0.7872  0.7603  0.7735  0.7919
# 1  10Cycle  0.8006  0.7712  0.8082  0.7893  0.8012

# %% [markdown]
# #### 🚩 9Cycle 결과
# - 상관관계 전처리
# **정확도: 0.7943, 정밀도: 0.7872, 재현율: 0.7603, F1:0.7735, AUC:0.7919**
#
# #### 🚩 10Cycle 결과
# - 임계값 조정
# **정확도: 0.8006, 정밀도: 0.7712, 재현율: 0.8082, F1: 0.7893, AUC: 0.8012**
#
# #### 💡 분석
# - 재현율을 높이기 위해 임계값을 조정한 결과 정밀도는 약간 하락하였지만, 전체적인 수치는 향상된 것을 확인함.
# - 정확도가 0.8정도가 나오는 것으로 보아 신뢰성이 있는 모델이라고 판단됨.
