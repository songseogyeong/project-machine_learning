# %% [markdown]
# # Company Bankruptcy Classifier Project (Logistic_Regression)
# ## 회사 파산 예측
# 1999~2009년 대만 경제 저널의 파산 데이터
#
# #### feature (95개)
#
# - X1 :이자 전 ROA(C) 및 이자 전 감가상각: 총 자산 수익률(C)
# - X2 :이자 전 ROA(A) 및 세후 %: 총 자산 수익률(A)
# - X3 :ROA (B) 이자 전, 세후 감가상각비: 총자산수익률(B)
# - X4 :영업총이익: 매출총이익/순매출액
# - X5 :실현매출총이익: 실현총이익/순매출액
# - X6 :영업이익률: 영업이익/ 순매출액
# - X7 :세전 순이자율: 세전이익/순매출액
# - X8 :세후 순이자율: 순이익/순매출액
# - X9 :비산업소득 및 지출/수입: 순영업외소득비율
# - X10: 지속이자율(세후): 당기순이익-처분손익 제외/순매출액
# - X11: 영업비용률: 영업비용/순매출액
# - X12: 연구개발비율: (연구개발비)/순매출액
# - X13: 현금흐름율: 영업/유동부채 현금흐름
# - X14: 이자부부채 이자율: 이자부부채/자본
# - X15: 세율(A): 유효세율
# - X16: 주당 순가치(B): 장부가액 주식(B)
# - X17: 주당 순 가치(A): 주당 순 가치(A)
# - X18: 주당 순 가치(C): 주당 순 가치(C)
# - X19: 지난 4계절의 지속 EPS: EPS- 순이익
# - X20: 주당 현금 흐름
# - X21: 주당 수익(Yuan ¥): 주당 매출
# - X22: 주당 영업 이익(Yuan ¥): 주당 영업 이익
# - X23: 주당 세전 순이익(Yuan ¥): 세전 주당순이익
# - X24: 실현매출총이익 성장률
# - X25: 영업이익 성장률: 영업이익 성장률
# - X26: 세후 순이익 성장률: 순이익 성장률
# - X27: 정기 순이익 성장률: 세후 성장률
# - X28: 지속순이익 증가율 : 당기순이익 제외 처분손익 증가율
# - X29: 총자산 증가율 : 총자산 증가율
# - X30: 순가치 증가율 : 총자본 증가율
# - X31: 총자산 수익률 증가율 비율 : 총자산 증가율
# - X32: 현금 재투자 %: 현금 재투자 비율
# - X33: 유동 비율
# - X34: 당좌 비율: 산성 테스트
# - X35: 이자 비용 비율: 이자 비용/총 수익
# - X36: 총 부채/총 순자산: 총 부채/자본 비율
# - X37: 부채 비율 %: 부채/총자산
# - X38: 순자산/자산: 자본/총자산
# - X39: 장기자금적합성비율(A): (장기부채+자본)/고정자산
# - X40: 차입의존: 이자부부채비용
# - X41: 우발부채/순자산: 우발부채/자본
# - X42: 영업이익/불입자본: 영업이익/자본
# - X43: 세전순이익/불입자본: 세전이익/자본
# - X44: 재고자산 및 매출채권/순액 값: (재고+미수금)/자본
# - X45: 총 자산 회전율
# - X46: 매출채권 회전율
# - X47: 평균 회수 일수: 미수금 일수
# - X48: 재고 회전율(회)
# - X49: 고정 자산 회전율
# - X50: 순자산 회전율( 배): 자기자본회전율
# - X51: 1인당 수익: 1인당 매출액
# - X52: 1인당 영업이익: 1인당 영업이익
# - X53: 1인당 배분율: 1인당 고정자산
# - X54: 총자산 대비 운전자본
# - X55: 당좌자산/총자산
# - X56: 유동 자산/총 자산
# - X57: 현금/총 자산
# - X58: 당좌 자산/유동 부채
# - X59: 현금/유동 부채
# - X60: 자산 유동 부채
# - X61: 부채 대비 운영 자금
# - X62: 재고/운전 자본
# - X63: 재고/유동 부채
# - X64: 유동 부채/부채
# - X65: 운전 자본/자본
# - X66: 유동 부채/자본
# - X67: 유동 자산에 대한 장기 부채
# - X68: 총 자산에 대한 이익 잉여금
# - X69: 총 수입/총 비용
# - X70: 총 비용/자산
# - X71: 유동 자산 회전율: 유동 자산 - 매출
# - X72: 빠른 자산 회전율: 빠른 자산 - 매출
# - X73: 운전 자본 회전율: 운전 자본 - 매출
# - X74: 현금 회전율: 현금 - 매출
# - X75: 현금 흐름 - 매출
# - X76: 고정 자산 - 자산
# - X77: 부채 대비 유동 부채
# - X78: 자본 대비 유동 부채
# - X79: 장기 부채 대비 자본
# - X80: 총 자산 대비 현금 흐름
# - X81: 부채 대비 현금 흐름
# - X82: 자산 대비 CFO
# - X83: 자본 대비 현금 흐름
# - X84: 유동 부채 유동 자산
# - X85: 부채-자산 플래그: 총 부채가 총 자산을 초과하는 경우 1, 그렇지 않으면 0
# - X86: 총 자산 대비 순이익
# - X87: GNP 가격 대비 총 자산
# - X88: 무신용 간격
# - X89: 매출 총 이익
# - X90: 순이익 주주 자기자본
# - X91: 자기자본에 대한 부채
# - X92: 재무 레버리지 정도(DFL)
# - X93: 이자보상비율(EBIT에 대한 이자 비용)
# - X94: 순이익 플래그: 지난 2년간 순이익이 마이너스인 경우 1, 그렇지 않은 경우 0
# - X95: 책임에 대한 형평성
#
# #### target
# - Y: 파산 여부

# %%
import matplotlib.pyplot as plt

# 한글 폰트 경로 설정
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
import pandas as pd

# 데이터 세트 호출
c_df = pd.read_csv('./datasets/CompanyBankruptcyPrediction.csv')
c_df
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %% [markdown]
# #### 📊 데이터 탐색

# %%
# 데이터 정보 확인
c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6819 entries, 0 to 6818
# Data columns (total 96 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Bankrupt?                                                 6819 non-null   int64
#  1    ROA(C) before interest and depreciation before interest  6819 non-null   float64
#  2    ROA(A) before interest and % after tax                   6819 non-null   float64
#  3    ROA(B) before interest and depreciation after tax        6819 non-null   float64
#  4    Operating Gross Margin                                   6819 non-null   float64
#  5    Realized Sales Gross Margin                              6819 non-null   float64
#  6    Operating Profit Rate                                    6819 non-null   float64
#  7    Pre-tax net Interest Rate                                6819 non-null   float64
# ...

# %%
# 결측치 확인
c_df.isna().sum().sum()
# Out:
# 0

# %%
# 중복행 확인
c_df.duplicated().sum()
# Out:
# 0

# %%
# 데이터 컬럼명 확인
c_df.columns
# Out:
# Index(['Bankrupt?', ' ROA(C) before interest and depreciation before interest',
#        ' ROA(A) before interest and % after tax',
#        ' ROA(B) before interest and depreciation after tax',
#        ' Operating Gross Margin', ' Realized Sales Gross Margin',
#        ' Operating Profit Rate', ' Pre-tax net Interest Rate',
#        ' After-tax net Interest Rate',
#        ' Non-industry income and expenditure/revenue',
#        ' Continuous interest rate (after tax)', ' Operating Expense Rate',
#        ' Research and development expense rate', ' Cash flow rate',
#        ' Interest-bearing debt interest rate', ' Tax rate (A)',
#        ' Net Value Per Share (B)', ' Net Value Per Share (A)',
#        ' Net Value Per Share (C)', ' Persistent EPS in the Last Four Seasons',
#        ' Cash Flow Per Share', ' Revenue Per Share (Yuan ¥)',
#        ' Operating Profit Per Share (Yuan ¥)',
#        ' Per Share Net profit before tax (Yuan ¥)',
# ...

# %%
# 타겟 데이터 비중 확인
c_df['Bankrupt?'].value_counts()
# Out:
# Bankrupt?
# 0    6599
# 1     220
# Name: count, dtype: int64

# %% [markdown]
# #### 🚩 결과
# 타겟 데이터 비중이 크게 차이남에 따라 전처리 시 under sampling을 진행하려 한다.
